# %% [markdown]
# <a href="https://colab.research.google.com/github/BahrulMunirF/Week2/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/Google Drive/kucing.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)     #konversi chanel BGR -> RGB
plt.imshow(img3)

# %% [markdown]
# TUGAS
# Berdasarkan praktikum bagian 1 dan 2 kerjakan beberapa tugas berikut :
# 1. Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga
# berubah?
# plt.figure(figsize=(5,5))
# plt.imshow(img5)
# 2. Tampilkan image dalam channel Red-Green dan Green-Blue saja!

# %%
#Red-Green

img2 = img
img3[:,:,0] = np.zeros([img3.shape[0], img3.shape[1]])
plt.imshow(img3)

# %%
#Green-Blue

img2 = img
img3[:,:,2] = np.zeros([img3.shape[0], img3.shape[1]])
plt.imshow(img3)

# %% [markdown]
# 3. Tampilkan image baris ke 20-250, kolom 20-250!

# %%
#Tampilkan image baris ke 20-250, kolom 20-250!

img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img[20:250, 20:250])

# %% [markdown]
# 4. Tampilkan image baris ke 7-27, semua kolom, channel Red saja!

# %%
img2 = img[7:27, 0:627]
img3[;, ;, 1] - 0
img3[:,:, 2] - 0
plt.imshow(img)
# Out:
#   File "<ipython-input-16-407efa0c92c0>", line 2
#     img3[;, ;, 1] - 0
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# 5. Buat 3 kotak berbagai ukuran dan warna yang berbeda dalam satu image.
# disarankan menggunakan bilangan acak/random!

# %%
img_gray = cv.imread('/content/drive/MyDrive//Google Drive/kucing.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB),(512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)
#simpan file image
#cv.imwrite('/content/drive/MyDrive//Google Drive/kucing.tiff',img5)

#tampilan plot dengan ukuran canvas yg lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# PertAnyAaN
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
# JAWAB :
# jika menggunakan matplotlib gambar kita ada ukuran panjang dan lebarnya
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16
# dan int32?
# JAWAB:
# perbedaanya terletak pada ukuran file gambar int16 lebih beasr daripada int32
# 3. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode
# berikut
# JAWAB:
# menampilkangambar di google colab hanya perlu menggunakan patches
# 4.Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib
# JAWAB:
# untuk import dan read pada gambar

# %% [markdown]
# Tugas

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(50,25))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img)
